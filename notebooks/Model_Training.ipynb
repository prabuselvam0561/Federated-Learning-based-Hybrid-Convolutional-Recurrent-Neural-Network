# %% [markdown]
# # Model Training
#
# This notebook demonstrates how to train the hybrid CRNN model on the IoT dataset.

# %%
from model_training import train_model
import numpy as np
import tensorflow as tf

# Generate synthetic data for demonstration
data = np.random.rand(1000, 50, 1)
labels = tf.keras.utils.to_categorical(np.random.randint(0, 10, size=(1000,)), num_classes=10)

# Train model
trained_model = train_model(data, labels)
print('Model training complete.')
